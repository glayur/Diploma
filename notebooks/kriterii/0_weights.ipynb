# %%
import pandas as pd

# %%
folder = Path(r'X:\00_ЛабГрад_ПО\09_Сотрудники\Глазов Ю.А\izhevsk\weights')
files = [f.name for f in folder.iterdir() if f.is_file()]
files
# Out:
# ['weights_20260212.csv']

# %%
file_path = folder / 'weights_20260212.csv'

# %%
weigths = pd.read_csv(file_path).iloc[:-1]

# %%
weigths
# Out:
#                                           Unnamed: 0  ЛЛМ  ЕП  УС  МЖ  ИР  ЛИ  \
# 0              Критерий интервала маршрута НГПТ (Н1)   20   5   8 NaN  14  10
# 1        Критерий времени работы маршрутов НГПТ (Н2)   10   5   4 NaN  14  10
# 2       Критерий класса подвижного состава НГПТ (Н3)    9   5  10 NaN  14  10
# 3       Критерий интермодальности маршрута НГПТ (Н4)   13  15  10 NaN   7  10
# 4        Критерий криволинейности маршрута НГПТ (Н5)    6   5   4 NaN  14   5
# 5         Критерий обособленности маршрута НГПТ (У1)   13  10  10 NaN  14  15
# 6  Критерий наличия мест концентрации ДТП на марш...    3   5   4 NaN   4   5
# 7  Критерий наличия неподходящих участков УДС на ...    4  10  10 NaN   5   5
# 8  Критерий доступности маршрута НГПТ для населен...   15  20  20 NaN   7  15
# 9  Критерий наличия якорных объектов притяжения в...    7  20  20 NaN   7  15
#
#    АТ  АД  РХ  Unnamed: 10 Unnamed: 11
# 0 NaN NaN NaN          9.0        12,5
# ...

# %%
# Out:
#                                           Unnamed: 0  ЛЛМ  ЕП  УС  МЖ  ИР  ЛИ  \
# 0              Критерий интервала маршрута НГПТ (Н1)   20   5   8 NaN  14  10
# 1        Критерий времени работы маршрутов НГПТ (Н2)   10   5   4 NaN  14  10
# 2       Критерий класса подвижного состава НГПТ (Н3)    9   5  10 NaN  14  10
# 3       Критерий интермодальности маршрута НГПТ (Н4)   13  15  10 NaN   7  10
# 4        Критерий криволинейности маршрута НГПТ (Н5)    6   5   4 NaN  14   5
# 5         Критерий обособленности маршрута НГПТ (У1)   13  10  10 NaN  14  15
# 6  Критерий наличия мест концентрации ДТП на марш...    3   5   4 NaN   4   5
# 7  Критерий наличия неподходящих участков УДС на ...    4  10  10 NaN   5   5
# 8  Критерий доступности маршрута НГПТ для населен...   15  20  20 NaN   7  15
# 9  Критерий наличия якорных объектов притяжения в...    7  20  20 NaN   7  15
#
#    АТ  АД  РХ  Unnamed: 10 Unnamed: 11
# 0 NaN NaN NaN          9.0        12,5
# ...
